# %% [markdown]
# ##Project#3: Exploratory Data Analysis using Databricks
# ####(Total Points: 15)
#
# ####Instruction:
# ##### Perform exploratory data analysis (EDA) to gain insights using Community Edition of Databricks.
# #### Use the Notebook "Project#3: Exploratory Data Analysis using Databricks" DBC file for the assigment
# ##### “Databricks Overview Labs CS 5165 | 6065 v1_1.dbc” file has been provided for review. It is in Canvas.
#
# #### Homework Tasks:
#
# #####1.  Calculate the Total count of Crimes for each of the 6 United States cities listed below using 2016 crime data in dbfs:/mnt/training/crime-data-2016
# #####2.  Provide Total count of different Types of Crimes for each of 6 United States cities listed below using crime-data-2016
# #####3.  Calculate the total Robbery count for each of the 3 United States cities listed below using crime-data-2016
# #####4.  Find the months with the Highest and Lowest Robbery counts for each of the 3 United States cities listed below using crime-data-2016
# #####5.  Combine all three cities robberies-per-month views into one and Find the month with the Highest and Lowest combined Robbery counts using crime-data-2016
# #####6.  Plot the robberies per month for each of the three cities, producing one Graph using the contents of combinedRobberiesByMonthDF
# #####7.  Find the "per capita robbery rates" using ther Hint below, and plot graph as above for the per capita robbery rates per month for each of the three cities, producing one Graph using the contents of robberyRatesByCityDF
# #####8.  Find the monthly HOMICIDE counts for each of the 2 United States cities listed below using crime-data-2016, and Combine both cities HOMICIDE-per-month views into one and Find the month with the Highest and Lowest combined HOMICIDE-per-month counts. See Question 6.
# #####9. Find the "per capita HOMICIDE rates" using the Hint in Qn 7, and plot graph as above for the per capita HOMICIDE rates per month for each of the two cities, producing one Graph using the contents of HOMICIDERatesByCityDF
# #####10. A stretch goal to address a Data Science question on predicting crimes for a city as a time series model. How would you predict future values for monthly Robbery count rate for Log Angeles using the historical values from crime-data-2016.  Data Science is a multi-year discipline.  I am not expecting anything fancy.  There is no wrong answer. I do expect students to explore and give their best shot.
#
#
# Submission:
# 1.	Export the completed "Project#3: Exploratory Data Analysis using Databricks.dbc" as DBC Archive file with all the information in Blackboard
# 2.	Your spark code/command and results included

# %% [markdown]
# ### Exploratory Data Analysis using Databricks
# Perform exploratory data analysis (EDA) to gain insights from a data lake.
#
# ## Instructions
#
# In `dbfs:/mnt/training/crime-data-2016`, there are a number of Parquet files containing 2016 crime data from seven United States cities:
#
# * New York
# * Los Angeles
# * Chicago
# * Philadelphia
# * Dallas
# * Boston
#
#
# The data is cleaned up a little, but has not been normalized. Each city reports crime data slightly differently, so
# examine the data for each city to determine how to query it properly.
#
# Your job is to use some of this data to gain insights about certain kinds of crimes.

# %% [markdown]
# ### Getting Started
#
# Run the following cell to configure our "classroom."

# %%
# %run ./Includes/Project3-Setup
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
# ...

# %%
print("username: " + username)
print("userhome: " + userhome)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# ## Question 1:  Calculate the Total count of Crimes for each of the 6 United States cities listed below using 2016 crime data in dbfs:/mnt/training/crime-data-2016:
#
# * New York
# * Los Angeles
# * Chicago
# * Philadelphia
# * Dallas
# * Boston
#
#
# **Hint:**
#
# Start by creating DataFrames for Los Angeles, Philadelphia, and Dallas data.
#
# Use `spark.read.parquet` to create named DataFrames for the files you choose.
#
# To read in the parquet file, use `crimeDataNewYorkDF = spark.read.parquet("/mnt/training/crime-data-2016/Crime-Data-New-York-2016.parquet")`
#
#
# Use the following view names:
#
# | City          | DataFrame Name            | Path to DBFS file
# | ------------- | ------------------------- | -----------------
# | Los Angeles   | `crimeDataLosAngelesDF`   | `dbfs:/mnt/training/crime-data-2016/Crime-Data-Los-Angeles-2016.parquet`
# | Philadelphia  | `crimeDataPhiladelphiaDF` | `dbfs:/mnt/training/crime-data-2016/Crime-Data-Philadelphia-2016.parquet`
# | Dallas        | `crimeDataDallasDF`       | `dbfs:/mnt/training/crime-data-2016/Crime-Data-Dallas-2016.parquet`
# | etc...        |

# %% [markdown]
# **Hint:**  Los Angeles

# %%
# TODO

#Loading the dataframe for NewYork
crimeDataNewYorkDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-New-York-2016.parquet/")
crimeDataLosAngelesDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-Los-Angeles-2016.parquet/")
crimeDataChicagoDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-Chicago-2016.parquet/")
crimeDataPhiladelphiaDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-Philadelphia-2016.parquet/")
crimeDataDallasDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-Dallas-2016.parquet/")
crimeDataBostonDF = spark.read.parquet("dbfs:/mnt/training/crime-data-2016/Crime-Data-Boston-2016.parquet/")

print("Total count of crimes in Philadelphia" , crimeDataPhiladelphiaDF.distinct().count())
print("Total count of crimes in Dallas" , crimeDataDallasDF.distinct().count())
print("Total count of crimes in Chicago" , crimeDataChicagoDF.distinct().count())
print("Total count of crimes in LosAngeles" , crimeDataLosAngelesDF.distinct().count())
print("Total count of crimes in NewYork" , crimeDataNewYorkDF.distinct().count())
print("Total count of crimes in Boston" , crimeDataBostonDF.distinct().count())
# Out:
# Total count of crimes in Philadelphia 168664
# Total count of crimes in Dallas 99642
# Total count of crimes in Chicago 267872
# Total count of crimes in LosAngeles 217945
# Total count of crimes in NewYork 468241
# Total count of crimes in Boston 218586

# %% [markdown]
# -sandbox
# ## Question 2: Provide Total count of different Types of Crimes for each of 6 United States cities listed below using crime-data-2016:
# * New York
# * Los Angeles
# * Chicago
# * Philadelphia
# * Dallas
# * Boston
#
# ### Notice in the Dataframes:
# * The `crimeDataNewYorkDF` and `crimeDataBostonDF` DataFrames use different names for the columns.
# * The data itself is formatted differently and different names are used for similar concepts.
#
# This is common in a Data Lake. Often files are added to a Data Lake by different groups at different times. The advantage of this strategy is that anyone can contribute information to the Data Lake and that Data Lakes scale to store arbitrarily large and diverse data. The tradeoff for this ease in storing data is that it doesn’t have the rigid structure of a traditional relational data model, so the person querying the Data Lake will need to normalize data before extracting useful insights.
#
# ## Same Type of Data, Different Structure
#
# Examine crime data to determine how to extract homicide statistics.
#
# Because the data sets are pooled together in a Data Lake, each city may use different field names and values to indicate homicides, dates, etc.
#
# For example:
# * Some cities use the value "HOMICIDE", "CRIMINAL HOMICIDE" or "MURDER".
# * In the New York data, the column is named `offenseDescription` while in the Boston data, the column is named `OFFENSE_CODE_GROUP`.
# * In the New York data, the date of the event is in the `reportDate`, while in the Boston data, there is a single column named `MONTH`.

# %% [markdown]
# **Hint:** Los Angeles

# %%
type_of_crimeDF_NY = crimeDataNewYorkDF.groupBy("offenseDescription")\
.count()
display(type_of_crimeDF_NY)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type_of_crimeDF_LA = crimeDataLosAngelesDF.groupBy("crimeCodeDescription")\
.count()
display(type_of_crimeDF_LA)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type_of_crimeDF_Chicago = crimeDataChicagoDF.groupBy("primaryType")\
.count()
display(type_of_crimeDF_Chicago)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type_of_crimeDF_Philadelphia = crimeDataPhiladelphiaDF.groupBy("ucr_general_description")\
.count()
display(type_of_crimeDF_Philadelphia)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type_of_crimeDF_Dallas = crimeDataDallasDF.groupBy("typeOfIncident")\
.count()
display(type_of_crimeDF_Dallas)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
type_of_crimeDF_Boston = crimeDataBostonDF.groupBy("offense_code_group")\
.count()
display(type_of_crimeDF_Boston)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# TODO
print("Type of crimes in Los Angeles" ,
      crimeDataLosAngelesDF.select("crimeCode").distinct().count())
print("Type of crimes in Philadelphia",
      crimeDataPhiladelphiaDF.select("ucr_general").distinct().count())
print("Type of crimes in Boston" , 
      crimeDataBostonDF.select("OFFENSE_CODE").distinct().count())
print("Type of crimes in Chicago" , 
      crimeDataChicagoDF.select("primaryType").distinct().count())
print("Type of crimes in NewYork" , 
      crimeDataNewYorkDF.select("keyCOde").distinct().count())
print("Type of crimes in Dallas" , 
      crimeDataDallasDF.select("typeOfIncident").distinct().count())
# Out:
# Type of crimes in Los Angeles 128
# Type of crimes in Philadelphia 26
# Type of crimes in Boston 221
# Type of crimes in Chicago 33
# Type of crimes in NewYork 67
# Type of crimes in Dallas 370

# %% [markdown]
# -sandbox
# ## Question 3: Calculate the total Robbery count for each of the 3 United States cities listed below using crime-data-2016:
# * Los Angeles
# * Philadelphia
# * Dallas
#
# **Hint:**  For each table, examine the data to figure out how to extract _robbery_ statistics.
#
# Each city uses different values to indicate robbery. Commonly used terminology is "larceny", "burglary" or "robbery." These challenges are common in data lakes.  To simplify things, restrict yourself to only the word "robbery" (and not attempted-roberty, larceny, or burglary).
#
# Explore the data for the three cities until you understand how each city records robbery information. If you don't want to worry about upper- or lower-case,
# remember to use the DataFrame `lower()` method to converts column values to lowercase.
#
# Create a DataFrame containing only the robbery-related rows, as shown in the table below.
#
# **Hint:** For each table, focus your efforts on the column listed below.
#
# Focus on the following columns for each table:
#
# | DataFrame Name            | Robbery DataFrame Name  | Column
# | ------------------------- | ----------------------- | -------------------------------
# | `crimeDataLosAngelesDF`   | `robberyLosAngelesDF`   | `crimeCodeDescription`
# | `crimeDataPhiladelphiaDF` | `robberyPhiladelphiaDF` | `ucr_general_description`
# | `crimeDataDallasDF`       | `robberyDallasDF`       | `typeOfIncident`

# %%
crimeDataLosAngelesDF.createOrReplaceTempView("los_angeles")
crimeDataLosAngelesDF.write.saveAsTable("losangelestable_2")
crimeDataPhiladelphiaDF.createOrReplaceTempView("philadelphia")
crimeDataPhiladelphiaDF.write.saveAsTable("philadelphiatable_2")
crimeDataDallasDF.createOrReplaceTempView("Dallas")
crimeDataDallasDF.write.saveAsTable("Dallas_table_2")

# %%
# %sql 
update losangelestable_2 SET crimeCodeDescription = LOWER(crimeCodeDescription)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>217945</td></tr></tbody></table></div>

# %%
# %sql
update Dallas_table_2 SET typeOfIncident = LOWER(typeOfIncident)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>99642</td></tr></tbody></table></div>

# %%
# %sql
update philadelphiatable_2 SET ucr_general_description = LOWER(ucr_general_description)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>168664</td></tr></tbody></table></div>

# %%
robberyLosAngelesDF = spark.sql("select COUNT(crimeCodeDescription) AS roberryLosAngelesDF from losangelestable_2 where crimeCodeDescription  ilike '%ROBBERY%'")
display(robberyLosAngelesDF)

robberyPhiladelphiaDF = spark.sql("select COUNT(ucr_general_description) AS robberyPhiladelphiaDF from philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%'")
display(robberyPhiladelphiaDF)

robberyDallasDF = spark.sql("select COUNT(typeOfIncident) AS robberyDallasDF from Dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%'")
display(robberyDallasDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>roberryLosAngelesDF</th></tr></thead><tbody><tr><td>10275</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>robberyPhiladelphiaDF</th></tr></thead><tbody><tr><td>6149</td></tr></tbody></table></div>
# <style scoped>
# ...

# %% [markdown]
# **Hint:** Los Angeles

# %% [markdown]
# -sandbox
# ## Question 4: Find the months with the Highest and Lowest Robbery counts for each of the 3 United States cities listed below using crime-data-2016:
# * Los Angeles
# * Philadelphia
# * Dallas
#
#
# **Hint:** Now that you have DataFrames of only the robberies in each city, create DataFrames for each city summarizing the number of robberies in each month.
#
# Your DataFrames must contain two columns:
# * `month`: The month number (e.g., 1 for January, 2 for February, etc.).
# * `robberies`: The total number of robberies in the month.
#
# Use the following DataFrame names and date columns:
#
#
# | City          | DataFrame Name     | Date Column
# | ------------- | ------------- | -------------
# | Los Angeles   | `robberiesByMonthLosAngelesDF` | `timeOccurred`
# | Philadelphia  | `robberiesByMonthPhiladelphiaDF` | `dispatch_date_time`
# | Dallas        | `robberiesByMonthDallasDF` | `startingDateTime`
#
# For each city, figure out which column contains the date of the incident. Then, extract the month from that date.

# %%
monthlyrobberiesLosAngelesDF = spark.sql("SELECT EXTRACT(MONTH FROM timeOccurred) as mon, count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%' group by mon order by mon asc ")
display(monthlyrobberiesLosAngelesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>1</td><td>835</td></tr><tr><td>2</td><td>757</td></tr><tr><td>3</td><td>810</td></tr><tr><td>4</td><td>804</td></tr><tr><td>5</td><td>888</td></tr><tr><td>6</td><td>827</td></tr><tr><td>7</td><td>931</td></tr><tr><td>8</td><td>850</td></tr><tr><td>9</td><td>834</td></tr><tr><td>10</td><td>932</td></tr><tr><td>11</td><td>849</td></tr><tr><td>12</td><td>958</td></tr></tbody></table></div>

# %%
robberiesByMonthLosAngelesDF = spark.sql("SELECT *from((SELECT EXTRACT(MONTH FROM timeOccurred) as mon,count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%'group by mon order by rob_count desc LIMIT 1) UNION (SELECT EXTRACT(MONTH FROM timeOccurred) as mon, count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%' group by mon order by rob_count asc LIMIT 1))")
display(robberiesByMonthLosAngelesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>12</td><td>958</td></tr><tr><td>2</td><td>757</td></tr></tbody></table></div>

# %%
monthlyrobberiesphiladelphiaDF = spark.sql("SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by mon asc")
display(monthlyrobberiesphiladelphiaDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>1</td><td>520</td></tr><tr><td>2</td><td>416</td></tr><tr><td>3</td><td>432</td></tr><tr><td>4</td><td>466</td></tr><tr><td>5</td><td>533</td></tr><tr><td>6</td><td>509</td></tr><tr><td>7</td><td>537</td></tr><tr><td>8</td><td>561</td></tr><tr><td>9</td><td>514</td></tr><tr><td>10</td><td>572</td></tr><tr><td>11</td><td>545</td></tr><tr><td>12</td><td>544</td></tr></tbody></table></div>

# %%
robberiesByMonthPhiladelphiaDF = spark.sql("SELECT * from(( SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by rob_count desc  LIMIT 1) UNION (SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by rob_count asc  LIMIT 1))")
display(robberiesByMonthPhiladelphiaDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>10</td><td>572</td></tr><tr><td>2</td><td>416</td></tr></tbody></table></div>

# %%
monthlyrobberiesDallasDF = spark.sql("SELECT EXTRACT(MONTH FROM startingDateTime) as mon, count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by mon asc")
display(monthlyrobberiesDallasDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>1</td><td>746</td></tr><tr><td>2</td><td>438</td></tr><tr><td>3</td><td>414</td></tr><tr><td>4</td><td>598</td></tr><tr><td>5</td><td>615</td></tr><tr><td>6</td><td>499</td></tr><tr><td>7</td><td>535</td></tr><tr><td>8</td><td>629</td></tr><tr><td>9</td><td>512</td></tr><tr><td>10</td><td>604</td></tr><tr><td>11</td><td>593</td></tr><tr><td>12</td><td>669</td></tr></tbody></table></div>

# %%
robberiesByMonthDallasDF = spark.sql("SELECT * from((SELECT EXTRACT(MONTH FROM startingDateTime) as mon,count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by rob_count desc LIMIT 1)UNION (SELECT EXTRACT(MONTH FROM startingDateTime) as mon, count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by rob_count asc LIMIT 1))")
display(robberiesByMonthDallasDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>1</td><td>746</td></tr><tr><td>3</td><td>414</td></tr></tbody></table></div>

# %% [markdown]
# **Hint:** Los Angeles

# %% [markdown]
# -sandbox
# ## Question 5: Combine all three cities robberies-per-month views into one and Find the month with the Highest and Lowest combined Robbery counts using crime-data-2016:
# * Los Angeles
# * Philadelphia
# * Dallas
#
#
# Create another DataFrame called `combinedRobberiesByMonthDF`, that combines all three robberies-per-month views into one.
# In creating this view, add a new column called `city`, that identifies the city associated with each row.
# The final view will have the following columns:
#
# * `city`: The name of the city associated with the row. (Use the strings "Los Angeles", "Philadelphia", and "Dallas".)
# * `month`: The month number associated with the row.
# * `robbery`: The number of robbery in that month (for that city).
#
# **Hint:** You may want to apply the `union()` method in this example to combine the three datasets.

# %%
monthlyrobberiesDallasDF.createOrReplaceTempView("monthlyrobberiesdallas")
monthlyrobberiesLosAngelesDF.createOrReplaceTempView("monthlyrobberiesLosAngeles")
monthlyrobberiesphiladelphiaDF.createOrReplaceTempView("monthlyrobberiesPhiladelphia")

# %%
display(monthlyrobberiesDallasDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th></tr></thead><tbody><tr><td>1</td><td>746</td></tr><tr><td>2</td><td>438</td></tr><tr><td>3</td><td>414</td></tr><tr><td>4</td><td>598</td></tr><tr><td>5</td><td>615</td></tr><tr><td>6</td><td>499</td></tr><tr><td>7</td><td>535</td></tr><tr><td>8</td><td>629</td></tr><tr><td>9</td><td>512</td></tr><tr><td>10</td><td>604</td></tr><tr><td>11</td><td>593</td></tr><tr><td>12</td><td>669</td></tr></tbody></table></div>

# %%
from pyspark.sql.functions import lower, col, split, lit
from pyspark.sql.functions import *
monthlyrobberiesLosAngelesDF = monthlyrobberiesLosAngelesDF.withColumn("city",lit("LosAngeles"))
display(monthlyrobberiesLosAngelesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
monthlyrobberiesphiladelphiaDF = monthlyrobberiesphiladelphiaDF.withColumn("city",lit("Philadelphia"))
display(monthlyrobberiesphiladelphiaDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
monthlyrobberiesDallasDF = monthlyrobberiesDallasDF.withColumn("city",lit("Dallas"))
display(monthlyrobberiesDallasDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
combinedRobberiesByMonthDF = monthlyrobberiesphiladelphiaDF.union(monthlyrobberiesDallasDF).union(monthlyrobberiesLosAngelesDF)

# %%
display(combinedRobberiesByMonthDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#Highest Crime Count out of all cities
highest_robbery_by_city = combinedRobberiesByMonthDF.sort("rob_count",ascending=False).take(1)
display(highest_robbery_by_city)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th><th>city</th></tr></thead><tbody><tr><td>12</td><td>958</td><td>LosAngeles</td></tr></tbody></table></div>

# %%
#Lowest Crime Count out of all cities
lowest_robbery_by_city = combinedRobberiesByMonthDF.sort("rob_count",ascending=True).take(1)
display(lowest_robbery_by_city)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>mon</th><th>rob_count</th><th>city</th></tr></thead><tbody><tr><td>3</td><td>414</td><td>Dallas</td></tr></tbody></table></div>

# %%
combined_month_robberies = spark.sql("SELECT * FROM ((SELECT EXTRACT(MONTH FROM timeOccurred) as mon, count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%' group by mon order by mon asc) UNION (SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by mon asc ) UNION (SELECT EXTRACT(MONTH FROM startingDateTime) as mon, count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by mon asc))")
display(combined_month_robberies)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
highest_month_robbery_combined = spark.sql("SELECT SUM(rob_count) as tot_rob_count, mon from (SELECT * FROM(SELECT EXTRACT(MONTH FROM timeOccurred) as mon, count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%' group by mon order by mon desc) UNION (SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by mon desc ) UNION (SELECT EXTRACT(MONTH FROM startingDateTime) as mon, count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by mon desc)) group by mon order by tot_rob_count desc LIMIT(1) ")
display(highest_month_robbery_combined)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tot_rob_count</th><th>mon</th></tr></thead><tbody><tr><td>2171</td><td>12</td></tr></tbody></table></div>

# %%
lowest_month_robbery_combined = spark.sql("SELECT SUM(rob_count) as tot_rob_count, mon from (SELECT * FROM(SELECT EXTRACT(MONTH FROM timeOccurred) as mon, count(crimeCodeDescription) as rob_count FROM losangelestable_2 where crimeCodeDescription ilike '%ROBBERY%' group by mon order by mon asc) UNION (SELECT EXTRACT(MONTH FROM dispatch_date_time) as mon, count(ucr_general_description) as rob_count FROM philadelphiatable_2 where ucr_general_description ilike '%ROBBERY%' group by mon order by mon asc ) UNION (SELECT EXTRACT(MONTH FROM startingDateTime) as mon, count(typeOfIncident) as rob_count FROM dallas_table_2 where typeOfIncident ILIKE '%ROBBERY%' group by mon order by mon asc))group by mon order by tot_rob_count asc LIMIT(1) ")
display(lowest_month_robbery_combined)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>tot_rob_count</th><th>mon</th></tr></thead><tbody><tr><td>1611</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# **Hint:** Combined 3 Cities

# %% [markdown]
# -sandbox
# ## Question 6: Plot the robberies per month for each of the three cities, producing one Graph using the contents of `combinedRobberiesByMonthDF`
#
# Adjust the plot options to configure the plot properly, as shown below:
#
# When you first run the cell, you'll get an HTML table as the result. To configure the plot:
#
# <img src="https://files.training.databricks.com/images/eLearning/capstone-plot-4.png" style="width: 362px; margin: 10px; border: 1px solid #aaaaaa; border-radius: 10px 10px 10px 10px"/>
#
# 1. Click the graph button.
# 2. If the plot doesn't look correct, click the **Plot Options** button.
# 3. Configure the plot similar to the following example.
#
# **Hint:** Order your results by `month`, then `city`.
#
# <img src="https://files.training.databricks.com/images/eLearning/capstone-plot-2.png" style="width: 268px; margin: 10px; border: 1px solid #aaaaaa; border-radius: 10px 10px 10px 10px"/>

# %%
# TODO

display(combinedRobberiesByMonthDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ## Question 7: Find the "per capita robbery rates" using ther Hint below, and plot graph as above for the per capita robbery rates per month for each of the three cities, producing one Graph using the contents of `robberyRatesByCityDF`:
# * Los Angeles
# * Philadelphia
# * Dallas
#
# While the above graph is interesting, it's flawed: it's comparing the raw numbers of robberies, not the per capita robbery rates.
#
# The DataFrame (already created) called `cityDataDF` (dbfs:/mnt/training/City-Data.parquet)  contains, among other data, estimated 2016 population values for all United States cities
# with populations of at least 100,000. (The data is from [Wikipedia](https://en.wikipedia.org/wiki/List_of_United_States_cities_by_population).)
#
# * Use the population values in that table to normalize the robberies so they represent per-capita values (total robberies divided by population).
# * Save your results in a DataFrame called `robberyRatesByCityDF`.
# * The robbery rate value must be stored in a new column, `robberyRate`.
#
# Next, graph the results, as above.

# %%
cityDataDF = spark.read.parquet("dbfs:/mnt/training/City-Data.parquet")
display(cityDataDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
LApop = cityDataDF.filter("city = 'Los Angeles'").select("estPopulation2016").collect()[0]["estPopulation2016"]
robberyRateLA = combinedRobberiesByMonthDF.withColumn("robberyRate", (combinedRobberiesByMonthDF.rob_count)/LApop).where("city = 'LosAngeles'")
Dallaspop = cityDataDF.filter("city = 'Dallas'").select("estPopulation2016").collect()[0]["estPopulation2016"]
robberyRateDallas = combinedRobberiesByMonthDF.withColumn("robberyRate", (combinedRobberiesByMonthDF.rob_count)/Dallaspop).where("city = 'Dallas'")
Phillypop = cityDataDF.filter("city = 'Philadelphia'").select("estPopulation2016").collect()[0]["estPopulation2016"]
robberyRatePhilly = combinedRobberiesByMonthDF.withColumn("robberyRate", (combinedRobberiesByMonthDF.rob_count)/Phillypop).where("city = 'Philadelphia'")
robberyRatesByCityDF = robberyRateLA.union(robberyRateDallas).union(robberyRatePhilly).sort("mon", ascending = True)
display(robberyRatesByCityDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
# TODO

display(robberyRatesByCityDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# -sandbox
# ## Question 8: Find the monthly HOMICIDE counts for each of the 2 United States cities listed below using crime-data-2016, and Combine both cities HOMICIDE-per-month views into one and Find the month with the Highest and Lowest combined HOMICIDE-per-month counts. See Question 6.
# * New York
# * Boston
#
# **Hint:**  Same Type of Data, Different Structure
# In this section, we examine crime data to determine how to extract homicide statistics.
# Each city may use different field names and values to indicate homicides, dates, etc.
# For example:
# * Some cities use the value "HOMICIDE", "CRIMINAL HOMICIDE" or "MURDER".
# * In the New York data, the column is named `offenseDescription` while in the Boston data, the column is named `OFFENSE_CODE_GROUP`.
# * In the New York data, the date of the event is in the `reportDate`, while in the Boston data, there is a single column named `MONTH`.
#
# To get started, create a temporary view containing only the homicide-related rows.
# At the same time, normalize the data structure of each table so all the columns (and their values) line up with each other.
# In the case of New York and Boston, here are the unique characteristics of each data set:
#
# | | Offense-Column        | Offense-Value          | Reported-Column  | Reported-Data Type |
# |-|-----------------------|------------------------|-----------------------------------|
# | New York | `offenseDescription`  | starts with "murder" or "homicide" | `reportDate`     | `timestamp`    |
# | Boston | `OFFENSE_CODE_GROUP`  | "Homicide"             | `MONTH`          | `integer`      |
# For the upcoming aggregation, you need to alter the New York data set to include a `month` column which can be computed from the `reportDate` column using the `month()` function. Boston already has this column.
#
# In this example, we use several functions in the `pyspark.sql.functions` library, and need to import:
#
# * `month()` to extract the month from `reportDate` timestamp data type.
# * `lower()` to convert text to lowercase.
# * `contains(mySubstr)` to indicate a string contains substring `mySubstr`.
#
# Also, note we use  `|`  to indicate a logical `or` of two conditions in the `filter` method.

# %%
from pyspark.sql.functions import lower, month

# %%
crimeDataNewYork = crimeDataNewYorkDF.select(lower(col('offenseDescription')),month('reportDate')).withColumnRenamed("lower(offenseDescription)", "offenseDescription").withColumnRenamed("month(reportDate)", "month")
crimeDataBYMonthNY = crimeDataNewYork.filter('offenseDescription ilike "%murder%" or offenseDescription ilike "%homicide%"').groupBy('month').count()
display(crimeDataNewYork)
display(crimeDataBYMonthNY)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
crimeDataBoston = crimeDataBostonDF.select(lower(col('OFFENSE_CODE_GROUP')),"month").withColumnRenamed("lower(OFFENSE_CODE_GROUP)", "offenseDescription")
crimeDataBYMonthBoston = crimeDataBoston.filter('OFFENSE_CODE_GROUP ilike "%murder%" or OFFENSE_CODE_GROUP ilike "%homicide%"').groupBy('month').count()
display(crimeDataBoston)
display(crimeDataBYMonthBoston)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
combinedhomicide = crimeDataBYMonthNY.union(crimeDataBYMonthBoston)
display(combinedhomicide)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
combinedhomicide = combinedhomicide.groupBy("month").sum("count").sort("month", ascending = True)
display(combinedhomicide)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>sum(count)</th></tr></thead><tbody><tr><td>1</td><td>29</td></tr><tr><td>2</td><td>21</td></tr><tr><td>3</td><td>29</td></tr><tr><td>4</td><td>36</td></tr><tr><td>5</td><td>38</td></tr><tr><td>6</td><td>42</td></tr><tr><td>7</td><td>45</td></tr><tr><td>8</td><td>50</td></tr><tr><td>9</td><td>43</td></tr><tr><td>10</td><td>29</td></tr><tr><td>11</td><td>30</td></tr><tr><td>12</td><td>32</td></tr></tbody></table></div>

# %%
highest_homicide_by_month = combinedhomicide.sort("sum(count)",ascending=False).take(1)
display(highest_homicide_by_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>sum(count)</th></tr></thead><tbody><tr><td>8</td><td>50</td></tr></tbody></table></div>

# %%
lowest_homicide_by_month = combinedhomicide.sort("sum(count)",ascending=True).take(1)
display(lowest_homicide_by_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>sum(count)</th></tr></thead><tbody><tr><td>2</td><td>21</td></tr></tbody></table></div>

# %%
#lowest and highest count by city
city_homicide_by_month_NY = crimeDataNewYorkDF.select(lower(col("offenseDescription")),month("reportDate")).withColumnRenamed("lower(offenseDescription)", "offenseDescription").withColumnRenamed("month(reportDate)", "month")
#display(city_homicide_by_month_NY)
city_homicide_by_month_NY = city_homicide_by_month_NY.filter('offenseDescription like "%murder%" or offenseDescription like "%homicide%"').groupBy("month").count().withColumn("city",lit("New York"))
display(city_homicide_by_month_NY)

#Boston
city_homicide_by_month_Boston = crimeDataBostonDF.select(lower(col("offense_code_group")),"month").withColumnRenamed("lower(offense_code_group)", "offenseDescription")
#display(city_homicide_by_month_NY)
city_homicide_by_month_Boston = city_homicide_by_month_Boston.filter('offenseDescription like "%murder%" or offenseDescription like "%homicide%"').groupBy("month").count().withColumn("city",lit("Boston"))
display(city_homicide_by_month_Boston)

combinedhomicidecity_by_month = city_homicide_by_month_NY.union(city_homicide_by_month_Boston)
display(combinedhomicidecity_by_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
#highest homicide by city and month

highest_city_homicide_by_month = combinedhomicidecity_by_month.sort("count", ascending = False).take(1)
display(highest_city_homicide_by_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th><th>city</th></tr></thead><tbody><tr><td>8</td><td>36</td><td>New York</td></tr></tbody></table></div>

# %%
#lowest homicide by city and month

lowest_city_homicide_by_month = combinedhomicidecity_by_month.sort("count", ascending = True).take(1)
display(lowest_city_homicide_by_month)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>month</th><th>count</th><th>city</th></tr></thead><tbody><tr><td>2</td><td>4</td><td>Boston</td></tr></tbody></table></div>

# %% [markdown]
# -sandbox
# ## Question 9: Find the "per capita HOMICIDE rates" using the Hint in Qn 7, and plot graph as above for the per capita HOMICIDE rates per month for each of the two cities, producing one Graph using the contents of HOMICIDERatesByCityDF

# %%
NY_pop = cityDataDF.filter("city = 'New York'").select("estPopulation2016").collect()[0]["estPopulation2016"]
Boston_pop =  cityDataDF.filter("city = 'Boston'").select("estPopulation2016").collect()[0]["estPopulation2016"]

NY_crime_data = city_homicide_by_month_NY.withColumn("city", lit("New York")).withColumnRenamed("count","homicides")
display(NY_crime_data)


Boston_crime_data = city_homicide_by_month_Boston.withColumn("city", lit("Boston")).withColumnRenamed("count","homicides")
combined_hom_DF = city_homicide_by_month_NY.union(city_homicide_by_month_Boston).sort("month", ascending = True)
display(combined_hom_DF)

bos_hom_rate = Boston_crime_data.withColumn("homicideRate", Boston_crime_data.homicides/Boston_pop)
display(bos_hom_rate)
new_york_hom_rate = NY_crime_data.withColumn("homicideRate", NY_crime_data.homicides/NY_pop)
display(new_york_hom_rate)

combined_hom_rate_DF = bos_hom_rate.union(new_york_hom_rate).sort("month", ascending = True)
display(combined_hom_rate_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
display(combined_hom_rate_DF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# -sandbox
# ## Question 10: A stretch goal to address a Data Science question on predicting crimes for a city as a time series model. How would you predict future values for monthly Robbery Count rate for Log Angeles using the historical values from crime-data-2016.  Data Science is a multi-year discipline.  I am not expecting anything fancy.  There is no wrong answer. I do expect students to explore and give their best shot.

# %%
display(monthlyrobberiesLosAngelesDF)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
from pyspark.sql.functions import collect_list
Y = monthlyrobberiesLosAngelesDF.select(collect_list(monthlyrobberiesLosAngelesDF['rob_count'])).first()[0]
X = [float(i) for i in Y]
print(X)
# Out:
# [835.0, 757.0, 810.0, 804.0, 888.0, 827.0, 931.0, 850.0, 834.0, 932.0, 849.0, 958.0]

# %%
from statsmodels.tsa.arima_model import ARIMA
from pyspark.sql.functions import collect_list
from sklearn.metrics import mean_squared_error

size_of_models = int(len(X) * 0.66)
train_model, test_model = X[0:size_of_models], X[size_of_models:len(X)]
recorded_values = [x for x in train_model]
prediction_values = list()

for t in range(len(test_model)):
	model = ARIMA(recorded_values, order=(0,0,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	y_hat = output[0][0]
	prediction_values.append(y_hat)
	observations = test_model[t]
	recorded_values.append(obs)
	print('predicted_values=%f, expected_values=%f' % (y_hat, observations))
# Out:
# predicted_values=836.000000, expected_values=850.000000
# predicted_values=851.250000, expected_values=834.000000
# predicted_values=863.111111, expected_values=932.000000
# predicted_values=872.600000, expected_values=849.000000
# predicted_values=880.363636, expected_values=958.000000

# %% [markdown]
# ## References
#
# The crime data used in this notebook comes from the following locations:
#
# | City          | Original Data
# | ------------- | -------------
# | Boston        | <a href="https://data.boston.gov/group/public-safety" target="_blank">https&#58;//data.boston.gov/group/public-safety</a>
# | Chicago       | <a href="https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2" target="_blank">https&#58;//data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2</a>
# | Dallas        | <a href="https://www.dallasopendata.com/Public-Safety/Police-Incidents/tbnj-w5hb/data" target="_blank">https&#58;//www.dallasopendata.com/Public-Safety/Police-Incidents/tbnj-w5hb/data</a>
# | Los Angeles   | <a href="https://data.lacity.org/A-Safe-City/Crime-Data-From-2010-to-Present/y8tr-7khq" target="_blank">https&#58;//data.lacity.org/A-Safe-City/Crime-Data-From-2010-to-Present/y8tr-7khq</a>
# | New Orleans   | <a href="https://data.nola.gov/Public-Safety-and-Preparedness/Electronic-Police-Report-2016/4gc2-25he/data" target="_blank">https&#58;//data.nola.gov/Public-Safety-and-Preparedness/Electronic-Police-Report-2016/4gc2-25he/data</a>
# | New York      | <a href="https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i" target="_blank">https&#58;//data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i</a>
# | Philadelphia  | <a href="https://www.opendataphilly.org/dataset/crime-incidents" target="_blank">https&#58;//www.opendataphilly.org/dataset/crime-incidents</a>
